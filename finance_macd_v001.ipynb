# %%
import pandas as pd
import numpy as np
import datetime as dt
import datetime, pytz
import seaborn as sns
#import plotly.graph_objects as go
import matplotlib.pyplot as plt
from matplotlib import pyplot
# Out:
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In D:\ProgramFiles\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
# Here We Convert Minutely Data to Daily Form 

def dateparse (time_in_secs):    
    
    return pytz.utc.localize(datetime.datetime.fromtimestamp(float(time_in_secs)))

# %%
df = pd.read_csv("../BTC_Correction_Listing_csv/data.csv",parse_dates=[0], date_parser=dateparse)

# %%
df.head(20)
# Out:
#                    Timestamp  Open  High   Low  Close  Volume_(BTC)  \
# 0  2011-12-31 16:52:00+00:00  4.39  4.39  4.39   4.39      0.455581
# 1  2011-12-31 16:53:00+00:00   NaN   NaN   NaN    NaN           NaN
# 2  2011-12-31 16:54:00+00:00   NaN   NaN   NaN    NaN           NaN
# 3  2011-12-31 16:55:00+00:00   NaN   NaN   NaN    NaN           NaN
# 4  2011-12-31 16:56:00+00:00   NaN   NaN   NaN    NaN           NaN
# 5  2011-12-31 16:57:00+00:00   NaN   NaN   NaN    NaN           NaN
# 6  2011-12-31 16:58:00+00:00   NaN   NaN   NaN    NaN           NaN
# 7  2011-12-31 16:59:00+00:00   NaN   NaN   NaN    NaN           NaN
# 8  2011-12-31 17:00:00+00:00   NaN   NaN   NaN    NaN           NaN
# 9  2011-12-31 17:01:00+00:00   NaN   NaN   NaN    NaN           NaN
# 10 2011-12-31 17:02:00+00:00   NaN   NaN   NaN    NaN           NaN
# 11 2011-12-31 17:03:00+00:00   NaN   NaN   NaN    NaN           NaN
# 12 2011-12-31 17:04:00+00:00   NaN   NaN   NaN    NaN           NaN
# 13 2011-12-31 17:05:00+00:00   NaN   NaN   NaN    NaN           NaN
# 14 2011-12-31 17:06:00+00:00   NaN   NaN   NaN    NaN           NaN
# 15 2011-12-31 17:07:00+00:00   NaN   NaN   NaN    NaN           NaN
# 16 2011-12-31 17:08:00+00:00   NaN   NaN   NaN    NaN           NaN
# 17 2011-12-31 17:09:00+00:00   NaN   NaN   NaN    NaN           NaN
# 18 2011-12-31 17:10:00+00:00   NaN   NaN   NaN    NaN           NaN
# 19 2011-12-31 17:11:00+00:00   NaN   NaN   NaN    NaN           NaN
#
#     Volume_(Currency)  Weighted_Price
# 0                 2.0            4.39
# 1                 NaN             NaN
# 2                 NaN             NaN
# 3                 NaN             NaN
# 4                 NaN             NaN
# 5                 NaN             NaN
# 6                 NaN             NaN
# 7                 NaN             NaN
# 8                 NaN             NaN
# 9                 NaN             NaN
# 10                NaN             NaN
# 11                NaN             NaN
# 12                NaN             NaN
# 13                NaN             NaN
# 14                NaN             NaN
# 15                NaN             NaN
# 16                NaN             NaN
# 17                NaN             NaN
# 18                NaN             NaN
# 19                NaN             NaN

# %%
df.isnull().sum()
# Out:
# Timestamp                  0
# Open                 1243472
# High                 1243472
# Low                  1243472
# Close                1243472
# Volume_(BTC)         1243472
# Volume_(Currency)    1243472
# Weighted_Price       1243472
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['Timestamp'], format="%Y-%d-%m %H:%M")

# %%
df['date'] = pd.to_datetime(df['date'])
df         = df.set_index(['date'])

# %%
df
# Out:
#                                           Timestamp      Open      High  \
# date
# 2011-12-31 16:52:00+00:00 2011-12-31 16:52:00+00:00      4.39      4.39
# 2011-12-31 16:53:00+00:00 2011-12-31 16:53:00+00:00       NaN       NaN
# 2011-12-31 16:54:00+00:00 2011-12-31 16:54:00+00:00       NaN       NaN
# 2011-12-31 16:55:00+00:00 2011-12-31 16:55:00+00:00       NaN       NaN
# 2011-12-31 16:56:00+00:00 2011-12-31 16:56:00+00:00       NaN       NaN
# ...                                             ...       ...       ...
# 2020-12-31 08:56:00+00:00 2020-12-31 08:56:00+00:00  28801.47  28829.42
# 2020-12-31 08:57:00+00:00 2020-12-31 08:57:00+00:00  28829.42  28863.90
# 2020-12-31 08:58:00+00:00 2020-12-31 08:58:00+00:00  28850.49  28900.52
# 2020-12-31 08:59:00+00:00 2020-12-31 08:59:00+00:00  28910.54  28911.52
# 2020-12-31 09:00:00+00:00 2020-12-31 09:00:00+00:00  28893.21  28928.49
#
#                                 Low     Close  Volume_(BTC)  \
# date
# 2011-12-31 16:52:00+00:00      4.39      4.39      0.455581
# 2011-12-31 16:53:00+00:00       NaN       NaN           NaN
# 2011-12-31 16:54:00+00:00       NaN       NaN           NaN
# 2011-12-31 16:55:00+00:00       NaN       NaN           NaN
# 2011-12-31 16:56:00+00:00       NaN       NaN           NaN
# ...                             ...       ...           ...
# 2020-12-31 08:56:00+00:00  28785.64  28829.42      0.965221
# 2020-12-31 08:57:00+00:00  28829.42  28857.06      2.368831
# 2020-12-31 08:58:00+00:00  28850.49  28882.82      2.466590
# 2020-12-31 08:59:00+00:00  28867.60  28881.30      7.332773
# 2020-12-31 09:00:00+00:00  28893.21  28928.49      5.757679
#
#                            Volume_(Currency)  Weighted_Price
# date
# 2011-12-31 16:52:00+00:00           2.000000        4.390000
# 2011-12-31 16:53:00+00:00                NaN             NaN
# 2011-12-31 16:54:00+00:00                NaN             NaN
# 2011-12-31 16:55:00+00:00                NaN             NaN
# 2011-12-31 16:56:00+00:00                NaN             NaN
# ...                                      ...             ...
# 2020-12-31 08:56:00+00:00       27804.572129    28806.429798
# 2020-12-31 08:57:00+00:00       68332.350629    28846.441863
# 2020-12-31 08:58:00+00:00       71232.784464    28879.056266
# 2020-12-31 08:59:00+00:00      211870.912660    28893.695831
# 2020-12-31 09:00:00+00:00      166449.709320    28909.166061
#
# [4727777 rows x 8 columns]

# %%
df.Low[df.Low==1.5]     = 540   # wrong data 
df.Close[df.Close==1.5] = 540   # wrong data
df.fillna(method='ffill', inplace = True)
# Out:
# D:\ProgramFiles\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# D:\ProgramFiles\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Close 

df_Close = df[["Close"]]
df_Close = df_Close.resample('D')[['Close']].last()

# %%
df
# Out:
#                                           Timestamp      Open      High  \
# date
# 2011-12-31 16:52:00+00:00 2011-12-31 16:52:00+00:00      4.39      4.39
# 2011-12-31 16:53:00+00:00 2011-12-31 16:53:00+00:00      4.39      4.39
# 2011-12-31 16:54:00+00:00 2011-12-31 16:54:00+00:00      4.39      4.39
# 2011-12-31 16:55:00+00:00 2011-12-31 16:55:00+00:00      4.39      4.39
# 2011-12-31 16:56:00+00:00 2011-12-31 16:56:00+00:00      4.39      4.39
# ...                                             ...       ...       ...
# 2020-12-31 08:56:00+00:00 2020-12-31 08:56:00+00:00  28801.47  28829.42
# 2020-12-31 08:57:00+00:00 2020-12-31 08:57:00+00:00  28829.42  28863.90
# 2020-12-31 08:58:00+00:00 2020-12-31 08:58:00+00:00  28850.49  28900.52
# 2020-12-31 08:59:00+00:00 2020-12-31 08:59:00+00:00  28910.54  28911.52
# 2020-12-31 09:00:00+00:00 2020-12-31 09:00:00+00:00  28893.21  28928.49
#
#                                 Low     Close  Volume_(BTC)  \
# date
# 2011-12-31 16:52:00+00:00      4.39      4.39      0.455581
# 2011-12-31 16:53:00+00:00      4.39      4.39      0.455581
# 2011-12-31 16:54:00+00:00      4.39      4.39      0.455581
# 2011-12-31 16:55:00+00:00      4.39      4.39      0.455581
# 2011-12-31 16:56:00+00:00      4.39      4.39      0.455581
# ...                             ...       ...           ...
# 2020-12-31 08:56:00+00:00  28785.64  28829.42      0.965221
# 2020-12-31 08:57:00+00:00  28829.42  28857.06      2.368831
# 2020-12-31 08:58:00+00:00  28850.49  28882.82      2.466590
# 2020-12-31 08:59:00+00:00  28867.60  28881.30      7.332773
# 2020-12-31 09:00:00+00:00  28893.21  28928.49      5.757679
#
#                            Volume_(Currency)  Weighted_Price
# date
# 2011-12-31 16:52:00+00:00           2.000000        4.390000
# 2011-12-31 16:53:00+00:00           2.000000        4.390000
# 2011-12-31 16:54:00+00:00           2.000000        4.390000
# 2011-12-31 16:55:00+00:00           2.000000        4.390000
# 2011-12-31 16:56:00+00:00           2.000000        4.390000
# ...                                      ...             ...
# 2020-12-31 08:56:00+00:00       27804.572129    28806.429798
# 2020-12-31 08:57:00+00:00       68332.350629    28846.441863
# 2020-12-31 08:58:00+00:00       71232.784464    28879.056266
# 2020-12-31 08:59:00+00:00      211870.912660    28893.695831
# 2020-12-31 09:00:00+00:00      166449.709320    28909.166061
#
# [4727777 rows x 8 columns]

# %%
# Low 

df_Low = df[["Low"]]
df_Low = df_Low.resample('D')['Low'].agg(['min'])

# %%
# High

df_High = df[["High"]]
df_High = df_High.resample('D')['High'].agg(['max'])

# %%
df_daily = pd.concat([df_Low,df_High,df_Close],axis=1)

# %%
df_daily
# Out:
#                                 min       max     Close  macd_blue  macd_red
# date
# 2011-12-31 00:00:00+00:00      4.39      4.39      4.39          0         0
# 2012-01-01 00:00:00+00:00      4.39      4.58      4.58          0         0
# 2012-01-02 00:00:00+00:00      4.58      5.00      5.00          0         0
# 2012-01-03 00:00:00+00:00      5.00      5.32      5.26          0         0
# 2012-01-04 00:00:00+00:00      4.93      5.29      5.19          0         0
# ...                             ...       ...       ...        ...       ...
# 2020-12-27 00:00:00+00:00  25329.90  28377.94  27295.11          5         7
# 2020-12-28 00:00:00+00:00  25770.00  27473.49  27261.43          5         7
# 2020-12-29 00:00:00+00:00  25831.85  27292.82  26626.63          5         7
# 2020-12-30 00:00:00+00:00  26205.00  28599.99  28193.92          5         7
# 2020-12-31 00:00:00+00:00  27896.34  29010.32  28928.49          5         7
#
# [3289 rows x 5 columns]

# %%
df_daily["macd_blue"].iloc[:26] = 0

# %%
df_daily["macd_red"].iloc[:12] = 0

# %%
for i in range(df_daily):
